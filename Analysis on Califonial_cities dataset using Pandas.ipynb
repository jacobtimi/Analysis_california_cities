# %% [markdown]
# import Califonial_cities dataset and perform the following activities on it:
# 1. Clean the data by getting rid of every null values
# 2. make cities column an index
# 3. describe the dataset
# 4. extract the city with highest population total, highest area land square meter and area water square meter
# 5. calculate the total area total square meter of Californian city
# 6. calculate the sum of the dataset along column axis

# %%
import pandas as pd 
import numpy as np

# %%
data =  pd.read_csv("C:\\Python class\\Datascience\\Datasets\\california_cities.csv") 
data
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 1             1  AgouraHills  34.153333 -118.761667        281.0
# 2             2      Alameda  37.756111 -122.274444          NaN
# 3             3       Albany  37.886944 -122.297778          NaN
# 4             4     Alhambra  34.081944 -118.135000        150.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# ...

# %%
data.isnull().any()
# Out:
# Unnamed: 0            False
# city                  False
# latd                  False
# longd                 False
# elevation_m            True
# elevation_ft           True
# population_total      False
# area_total_sq_mi       True
# area_land_sq_mi       False
# area_water_sq_mi       True
# area_total_km2         True
# area_land_km2          True
# area_water_km2         True
# area_water_percent     True
# Unnamed: 14            True
# Unnamed: 15            True
# dtype: bool

# %%
data_new = data.drop(labels=['Unnamed: 14', 'Unnamed: 15'], axis=1)
data_new
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 1             1  AgouraHills  34.153333 -118.761667        281.0
# 2             2      Alameda  37.756111 -122.274444          NaN
# 3             3       Albany  37.886944 -122.297778          NaN
# 4             4     Alhambra  34.081944 -118.135000        150.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# ...

# %%
data_new1 = data_new.fillna(0)
data_new1
# data_new1.isnull().any()
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 1             1  AgouraHills  34.153333 -118.761667        281.0
# 2             2      Alameda  37.756111 -122.274444          0.0
# 3             3       Albany  37.886944 -122.297778          0.0
# 4             4     Alhambra  34.081944 -118.135000        150.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# ...

# %%
ind = data_new1['city']
dataset = data_new1.set_index(ind)
dat = dataset.drop(labels=['city',], axis=1)
dat
# Out:
#              Unnamed: 0       latd       longd  elevation_m  elevation_ft  \
# city
# Adelanto              0  34.576111 -117.432778        875.0        2871.0
# AgouraHills           1  34.153333 -118.761667        281.0         922.0
# Alameda               2  37.756111 -122.274444          0.0          33.0
# Albany                3  37.886944 -122.297778          0.0          43.0
# Alhambra              4  34.081944 -118.135000        150.0         492.0
# ...                 ...        ...         ...          ...           ...
# Yountville          477  38.403056 -122.362222         30.0          98.0
# Yreka               478  41.726667 -122.637500        787.0        2582.0
# YubaCity            479  39.134722 -121.626111         18.0          59.0
# Yucaipa             480  34.030278 -117.048611        798.0        2618.0
# YuccaValley         481  34.133333 -116.416667       1027.0        3369.0
#
#              population_total  area_total_sq_mi  area_land_sq_mi  \
# ...

# %%
dat.describe()
# Out:
#        Unnamed: 0        latd       longd  elevation_m  elevation_ft  \
# count  482.000000  482.000000  482.000000   482.000000    482.000000
# mean   240.500000   36.095088 -119.837714   162.449896    553.048340
# std    139.285678    2.298006    2.147676   298.619572    992.646622
# min      0.000000   32.578333 -124.263333   -34.000000   -180.000000
# 25%    120.250000   33.977292 -121.954931    15.250000     62.000000
# 50%    240.500000   36.204722 -119.708611    50.500000    182.000000
# 75%    360.750000   37.886667 -117.977292   151.000000    502.500000
# max    481.000000   41.965000 -114.596389  2402.000000   7880.000000
#
#        population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# count      4.820000e+02        482.000000       482.000000        482.000000
# mean       6.489493e+04         18.365660        16.840981          1.586332
# std        2.032041e+05         36.306952        32.694647          9.480792
# ...

# %%
d = dataset['city']
d[dat['population_total'].argmax()]
# Out:
# 'LosAngeles'

# %%
d = dataset['city']
d[dat['area_land_sq_mi'].argmax()]
# Out:
# 'LosAngeles'

# %%
d = dataset['city']
d[dat['area_water_sq_mi'].argmax()]
# Out:
# 'SanFrancisco'

# %%
dat['area_total_sq_mi'].sum()
# Out:
# 8852.248

# %%
dat.sum()
# Out:
# Unnamed: 0            1.159210e+05
# latd                  1.739783e+04
# longd                -5.776178e+04
# elevation_m           7.830085e+04
# elevation_ft          2.665693e+05
# population_total      3.127936e+07
# area_total_sq_mi      8.852248e+03
# area_land_sq_mi       8.117353e+03
# area_water_sq_mi      7.646120e+02
# area_total_km2        2.230132e+04
# area_land_km2         2.081548e+04
# area_water_km2        1.493835e+03
# area_water_percent    2.528959e+03
# dtype: float64
